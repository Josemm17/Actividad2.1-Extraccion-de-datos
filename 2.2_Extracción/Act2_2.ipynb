# %%
import pandas as pd 
import numpy as np

# %%
df=pd.read_csv("Rio.csv")
df.head(5)
# Out:
#    Unnamed: 0       source                                   name  host_since  \
# 0           0  city scrape      Unbelievable Ocean View Apartment  2011-11-19
# 1           1  city scrape    EXCELENTE APARTAMENTO EM COPACABANA  2013-07-15
# 2           2  city scrape                  Comfort em Copacabana  2011-11-20
# 3           3  city scrape       Amazing Huge Apartment in Leblon  2011-04-25
# 4           4  city scrape  Lindo quarto sossegado para temporada  2011-05-04
#
#             host_location  host_response_time host_response_rate  \
# 0  Rio de Janeiro, Brazil  a few days or more                 0%
# 1  Rio de Janeiro, Brazil                 NaN                NaN
# 2  Rio de Janeiro, Brazil      within an hour               100%
# 3  Rio de Janeiro, Brazil                 NaN                NaN
# 4  Rio de Janeiro, Brazil  within a few hours               100%
#
#   host_acceptance_rate host_is_superhost host_neighbourhood  ...  \
# ...

# %%
#Filtro 1 Los registros de los host cuyo "host_response_rate" sea mayor a 95% y que no sean "superhost"

# Quitar el signo de porcentaje y convertir a número
#df['host_response_rate'] = df['host_response_rate'].str.replace('%', '').astype(float)

filtro1=df[~(df["host_is_superhost"] == "t") & (df["host_response_rate"] > 95)]
filtro1
# Out:
#        Unnamed: 0       source  \
# 4               4  city scrape
# 5               5  city scrape
# 7               7  city scrape
# 8               8  city scrape
# 10             10  city scrape
# ...           ...          ...
# 39487       39487  city scrape
# 39491       39491  city scrape
# 39494       39494  city scrape
# 39496       39496  city scrape
# 39497       39497  city scrape
#
#                                                     name  host_since  \
# 4                  Lindo quarto sossegado para temporada  2011-05-04
# 5         Apto de 2 qtos com vista para Lagoa e  garagem  2010-12-15
# 7                            Beautiful room for students  2011-05-04
# 8      Comfortable apart in Santa Teresa - Rio de Jan...  2011-11-22
# 10     Very Nice 2Br in Copacabana w. balcony, fast WiFi  2010-01-08
# ...                                                  ...         ...
# 39487                     350 metros da praia de Ipanema  2021-06-25
# ...

# %%
#Filtro 2 Los registros cuyas propiedades no tengan 1 baño
filtro2=df[~(df["bathrooms"]==1)]
filtro2
# Out:
#        Unnamed: 0       source  \
# 3               3  city scrape
# 5               5  city scrape
# 6               6  city scrape
# 12             12  city scrape
# 13             13  city scrape
# ...           ...          ...
# 39488       39488  city scrape
# 39489       39489  city scrape
# 39491       39491  city scrape
# 39494       39494  city scrape
# 39497       39497  city scrape
#
#                                                     name  host_since  \
# 3                       Amazing Huge Apartment in Leblon  2011-04-25
# 5         Apto de 2 qtos com vista para Lagoa e  garagem  2010-12-15
# 6                     Luxury Accommodation in Hip Leblon  2012-10-31
# 12       COPACABANA SEA BREEZE  -  RIO - 25  X Superhost  2010-06-27
# 13              Bright 6bed Penthouse Seconds from Beach  2010-01-16
# ...                                                  ...         ...
# 39488                       Suíte para casal na natureza  2024-07-01
# ...

# %%
#Filtro 3 Los registros que tengan un precio entre "$100 y $200 US" (Realizar conversión de moneda)
tipo_cambio=0.17 #USD A BRL

#Quitar signo de pesos y comas
#df['price'] = df['price'].str.replace('$', '')  
#df['price'] = df['price'].str.replace(',', '')   
# Convertir a número
df['price'] = df['price'].astype(float)



df['precio_usd'] = df['price'] * tipo_cambio
df["precio_usd"]

filtro3=df[(df["precio_usd"] >=  100) & (df["precio_usd"] <= 200)]
filtro3
# Out:
#        Unnamed: 0       source  \
# 1               1  city scrape
# 2               2  city scrape
# 6               6  city scrape
# 9               9  city scrape
# 11             11  city scrape
# ...           ...          ...
# 39489       39489  city scrape
# 39493       39493  city scrape
# 39494       39494  city scrape
# 39496       39496  city scrape
# 39497       39497  city scrape
#
#                                                     name  host_since  \
# 1                    EXCELENTE APARTAMENTO EM COPACABANA  2013-07-15
# 2                                  Comfort em Copacabana  2011-11-20
# 6                     Luxury Accommodation in Hip Leblon  2012-10-31
# 9       5 min a pé - Praia de Copacabana, Metrô, WiFi II  2011-03-18
# 11             Beautiful Modern Decorated Studio in Copa  2010-04-03
# ...                                                  ...         ...
# 39489  Apartamento completo ZS do Rio! Nos pés do Cri...  2017-06-13
# ...

# %%
#Filtro 4 Los registros que sean "instant_bookable" y que hallan verificado su perfil "host_identity_verified"
filtro4=df[(df["instant_bookable"] ==  "t") & (df["host_identity_verified"] == "t")]
filtro4
# Out:
#        Unnamed: 0       source                                         name  \
# 2               2  city scrape                        Comfort em Copacabana
# 13             13  city scrape     Bright 6bed Penthouse Seconds from Beach
# 15             15  city scrape  Djalma Ocean View Studio with Amazing Views
# 26             26  city scrape           400 meters from Leme beach | Pi401
# 30             30  city scrape              Perfect Copacabana near Ipanema
# ...           ...          ...                                          ...
# 39479       39479  city scrape                               Flat decorado.
# 39482       39482  city scrape                  Suíte aconchegante em Copa.
# 39484       39484  city scrape                        basic home minimalist
# 39493       39493  city scrape                                     Copaloft
# 39496       39496  city scrape   Apartamento na Barata Ribeiro - Copacabana
#
# ...

# %%
#Filtro 5 Los registros de los tipos de cuarto: "hotel room" o "Private room"
filtro5=df[(df["room_type"] == "Hotel room") | (df["room_type"] == "Private room")]
filtro5
# Out:
#        Unnamed: 0           source  \
# 2               2      city scrape
# 4               4      city scrape
# 7               7      city scrape
# 19             19      city scrape
# 27             27  previous scrape
# ...           ...              ...
# 39469       39469      city scrape
# 39478       39478      city scrape
# 39479       39479      city scrape
# 39482       39482      city scrape
# 39488       39488      city scrape
#
#                                               name  host_since  \
# 2                            Comfort em Copacabana  2011-11-20
# 4            Lindo quarto sossegado para temporada  2011-05-04
# 7                      Beautiful room for students  2011-05-04
# 19                  Fascinating Rio, on the hills!  2011-04-09
# 27                   Xenia's Room Casa São Conrado  2012-04-17
# ...                                            ...         ...
# 39469  Quarto privado 50m Praia de Copa - espaçoso  2017-02-18
# ...

# %%
#Filtro 6 Los registros que tengan mas de 4 accommodates
filtro6=df[(df["accommodates"]>4)]
filtro6
# Out:
#        Unnamed: 0       source  \
# 3               3  city scrape
# 5               5  city scrape
# 6               6  city scrape
# 10             10  city scrape
# 13             13  city scrape
# ...           ...          ...
# 39489       39489  city scrape
# 39491       39491  city scrape
# 39495       39495  city scrape
# 39496       39496  city scrape
# 39497       39497  city scrape
#
#                                                     name  host_since  \
# 3                       Amazing Huge Apartment in Leblon  2011-04-25
# 5         Apto de 2 qtos com vista para Lagoa e  garagem  2010-12-15
# 6                     Luxury Accommodation in Hip Leblon  2012-10-31
# 10     Very Nice 2Br in Copacabana w. balcony, fast WiFi  2010-01-08
# 13              Bright 6bed Penthouse Seconds from Beach  2010-01-16
# ...                                                  ...         ...
# 39489  Apartamento completo ZS do Rio! Nos pés do Cri...  2017-06-13
# ...

# %%
filtro1.to_csv("Actividad2.2_filtro1.csv")
filtro2.to_csv("Actividad2.2_filtro2.csv")
filtro3.to_csv("Actividad2.2_filtro3.csv")
filtro4.to_csv("Actividad2.2_filtro4.csv")
filtro5.to_csv("Actividad2.2_filtro5.csv")
filtro6.to_csv("Actividad2.2_filtro6.csv")
